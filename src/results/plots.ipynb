# %%
import matplotlib.pyplot as plt
plt.style.use('dark_background')

# %%
fig, ax = plt.subplots()
plt.title("Transformer")
plt.xlabel("Epochs")
plt.ylabel("MSE")
plt.grid(True)
# Train loss through epochs
y1 = [1.05644, 1.03086, 1.01714, 1.00559, 0.99202, 0.97439, 0.95137, 0.92506, 0.88759, 0.82456, 0.76444, 0.69671, 0.57303, 0.50381, 0.45914, 0.42502, 0.39308, 0.35949, 0.32629, 0.29404, 0.26689, 0.24031, 0.21881, 0.20106, 0.18646, 0.17394, 0.16302, 0.15378, 0.14598, 0.13876, 0.13263, 0.12688, 0.12168, 0.11695, 0.11251, 0.10814, 0.10424, 0.10111, 0.09764, 0.0943]
x1 = range(1, len(y1)+1)
# Test loss through epochs
y2 = [1.02584, 1.02113, 0.99846, 1.00494, 0.97102, 0.94599, 0.91527, 0.88143, 0.82701, 0.72478, 0.6673, 0.52301, 0.43675, 0.40473, 0.38269, 0.33079, 0.30652, 0.27225, 0.26275, 0.2301, 0.21104, 0.19692, 0.18105, 0.17461, 0.16649, 0.15781, 0.15753, 0.15046, 0.1566, 0.15292, 0.14717, 0.14325, 0.14559, 0.15014, 0.15348, 0.15103, 0.14878, 0.15591, 0.15073, 0.15389]
x2 = range(1, len(y2)+1)
plt.plot(x1, y1, marker='.', label="Train running loss")
plt.plot(x2, y2, marker='.', label="Test loss")
plt.legend(loc = "lower left")
ax.text(x1[-1], y1[-1], y1[-1], fontdict=None)
ax.text(x2[-1], y2[-1], y2[-1], fontdict=None)


plt.show()

# %%
fig, ax = plt.subplots()
plt.title("MLP Baseline")
plt.xlabel("Epochs")
plt.ylabel("MSE")
plt.grid(True)
# Train loss through epochs
y1 = [1.018, 0.986, 0.965, 0.941, 0.935, 0.922, 0.908, 0.900, 0.888, 0.872, 0.865, 0.861, 0.851, 0.846, 0.841, 0.834, 0.829, 0.822, 0.816, 0.815]
x1 = range(1, len(y1)+1)
# Test loss through epochs
y2 =  [1.018, 0.988, 0.972, 0.964, 0.952, 0.946, 0.942, 0.941, 0.934, 0.935, 0.936, 0.937, 0.931, 0.940, 0.940, 0.946, 0.936, 0.946, 0.941, 0.938]
x2 = range(1, len(y2)+1)
plt.plot(x1, y1, marker='.', label="Train running loss")
plt.plot(x2, y2, marker='.', label="Test loss")
plt.legend(loc = "lower left")
ax.text(x1[-1], y1[-1], y1[-1], fontdict=None)
ax.text(x2[-1], y2[-1], y2[-1], fontdict=None)


plt.show()

# %%
fig, ax = plt.subplots()
plt.title("LSTM")
plt.xlabel("Epochs")
plt.ylabel("MSE")
plt.grid(True)
# Train loss through epochs
y1 = [1.051, 1.025, 1.006, 1.006, 0.999, 0.995, 0.985, 0.989, 0.981, 0.978, 0.967, 0.975, 0.974, 0.969, 0.966, 0.964, 0.961, 0.965, 0.959, 0.954, 0.954, 0.955, 0.953, 0.951, 0.949, 0.944, 0.951, 0.940, 0.939, 0.937, 0.942, 0.937, 0.937, 0.933, 0.932, 0.927, 0.929, 0.926, 0.921, 0.926, 0.925, 0.926, 0.917, 0.917, 0.918, 0.917, 0.915, 0.919, 0.919, 0.911]
x1 = range(1, len(y1)+1)
# Test loss through epochs
y2 = [1.015, 0.988, 0.979, 0.988, 0.967, 0.962, 0.959, 0.953, 0.952, 0.951, 0.948, 0.945, 0.956, 0.942, 0.941, 0.938, 0.937, 0.938, 0.935, 0.932, 0.932, 0.931, 0.929, 0.930, 0.927, 0.928, 0.925, 0.924, 0.923, 0.923, 0.921, 0.922, 0.921, 0.917, 0.919, 0.915, 0.914, 0.914, 0.914, 0.917, 0.912, 0.912, 0.912, 0.912, 0.910, 0.911, 0.907, 0.911, 0.909, 0.914]
x2 = range(1, len(y2)+1)
plt.plot(x1, y1, marker='.', label="Train running loss")
plt.plot(x2, y2, marker='.', label="Test loss")
plt.legend(loc = "lower left")
ax.text(x1[-1], y1[-1]-0.01, y1[-1], bbox=dict(facecolor='blue', alpha=1), fontdict=None)
ax.text(x2[-1], y2[-1]+0.005, y2[-1], color="black", bbox=dict(facecolor='yellow', alpha=1), fontdict=None)


plt.show()

# %%
fig, ax = plt.subplots()
plt.title("Test loss comparison")
plt.xlabel("Epochs")
plt.ylabel("MSE")
plt.grid(True)

# MLP test loss through epochs
y1 = [1.018, 0.988, 0.972, 0.964, 0.952, 0.946, 0.942, 0.941, 0.934, 0.935, 0.936, 0.937, 0.931, 0.940, 0.940, 0.946, 0.936, 0.946, 0.941, 0.938]
x1 = range(1, len(y1)+1)
# LSTM test loss through epochs
y2 =  [1.015, 0.988, 0.979, 0.988, 0.967, 0.962, 0.959, 0.953, 0.952, 0.951, 0.948, 0.945, 0.956, 0.942, 0.941, 0.938, 0.937, 0.938, 0.935, 0.932, 0.932, 0.931, 0.929, 0.930, 0.927, 0.928, 0.925, 0.924, 0.923, 0.923, 0.921, 0.922, 0.921, 0.917, 0.919, 0.915, 0.914, 0.914, 0.914, 0.917, 0.912, 0.912, 0.912, 0.912, 0.910, 0.911, 0.907, 0.911, 0.909, 0.914]
x2 = range(1, len(y2)+1)
# Transformer test loss through epochs
y3 = [1.02584, 1.02113, 0.99846, 1.00494, 0.97102, 0.94599, 0.91527, 0.88143, 0.82701, 0.72478, 0.6673, 0.52301, 0.43675, 0.40473, 0.38269, 0.33079, 0.30652, 0.27225, 0.26275, 0.2301, 0.21104, 0.19692, 0.18105, 0.17461, 0.16649, 0.15781, 0.15753, 0.15046, 0.1566, 0.15292, 0.14717, 0.14325, 0.14559, 0.15014, 0.15348, 0.15103, 0.14878, 0.15591, 0.15073, 0.15389]
x3 = range(1, len(y3)+1)
plt.plot(x1, y1, marker='.', label="MLP")
plt.plot(x2, y2, marker='.', label="LSTM")
plt.plot(x3, y3, marker='.', label="Transformer")
plt.legend(loc = "lower left")
ax.text(x1[-1], y1[-1], y1[-1], fontdict=None)
ax.text(x2[-1], y2[-1], y2[-1], fontdict=None)
ax.text(x3[-1], y3[-1], y3[-1], fontdict=None)

plt.show()
